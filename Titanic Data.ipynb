# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename='train.csv'
titanic_df = pd.read_csv(filename)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Display the first few rows of the dataset
print(titanic_df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Check for missing values
print(titanic_df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Impute missing values (for simplicity, we'll fill missing values with median/mean)
titanic_df['Age'].fillna(titanic_df['Age'].median(), inplace=True)
titanic_df['Embarked'].fillna(titanic_df['Embarked'].mode()[0], inplace=True)
titanic_df['Fare'].fillna(titanic_df['Fare'].mean(), inplace=True)
titanic_df['Cabin'].fillna('Unknown', inplace=True)

# Display the updated DataFrame
print(titanic_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked
# 0        0         A/5 21171   7.2500  Unknown        S
# 1        0          PC 17599  71.2833      C85        C
# 2        0  STON/O2. 3101282   7.9250  Unknown        S
# 3        0            113803  53.1000     C123        S
# 4        0            373450   8.0500  Unknown        S
# ..     ...               ...      ...      ...      ...
# 886      0            211536  13.0000  Unknown        S
# 887      0            112053  30.0000      B42        S
# 888      2        W./C. 6607  23.4500  Unknown        S
# 889      0            111369  30.0000     C148        C
# 890      0            370376   7.7500  Unknown        Q
#
# [891 rows x 12 columns]

# %%
filename='train.csv'
titanic_df = pd.read_csv(filename)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Drop irrelevant columns
titanic_df.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)

# Display the updated DataFrame
print(titanic_df)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
# Convert categorical variables to numerical
titanic_df['Sex'] = titanic_df['Sex'].map({'male': 0, 'female': 1})
titanic_df = pd.get_dummies(titanic_df, columns=['Embarked', 'Pclass'], drop_first=True)
print(titanic_df)
# Out:
#      Survived  Sex   Age  SibSp  Parch     Fare Cabin  Embarked_Q  Embarked_S  \
# 0           0    0  22.0      1      0   7.2500   NaN       False        True
# 1           1    1  38.0      1      0  71.2833   C85       False       False
# 2           1    1  26.0      0      0   7.9250   NaN       False        True
# 3           1    1  35.0      1      0  53.1000  C123       False        True
# 4           0    0  35.0      0      0   8.0500   NaN       False        True
# ..        ...  ...   ...    ...    ...      ...   ...         ...         ...
# 886         0    0  27.0      0      0  13.0000   NaN       False        True
# 887         1    1  19.0      0      0  30.0000   B42       False        True
# 888         0    1   NaN      1      2  23.4500   NaN       False        True
# 889         1    0  26.0      0      0  30.0000  C148       False       False
# 890         0    0  32.0      0      0   7.7500   NaN        True       False
#
#      Pclass_2  Pclass_3
# 0       False      True
# 1       False     False
# 2       False      True
# 3       False     False
# 4       False      True
# ..        ...       ...
# 886      True     False
# 887     False     False
# 888     False      True
# 889     False     False
# 890     False      True
#
# [891 rows x 11 columns]

# %%
# Descriptive statistics
print(titanic_df.describe())
# Out:
#          Survived         Sex         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    0.352413   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.477990   14.526497    1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    1.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    1.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Visualize the survival count
sns.countplot(x='Survived', data=titanic_df)
plt.title('Survival Count')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Explore survival rate based on Pclass
sns.barplot(x='Pclass_2', y='Survived', data=titanic_df)
plt.title('Survival Rate by Pclass')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Explore survival rate based on Sex
sns.barplot(x='Sex', y='Survived', data=titanic_df)
plt.title('Survival Rate by Sex')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Explore survival rate based on Age
sns.histplot(x='Age', hue='Survived', data=titanic_df, kde=True)
plt.title('Survival by Age')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Explore correlations between numerical variables
numeric_columns = titanic_df.select_dtypes(include=[np.number]).columns
correlation_matrix = titanic_df[numeric_columns].corr()

# Plot the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Handling Outliers in 'Fare'
sns.boxplot(x='Fare', data=titanic_df)
plt.title('Boxplot of Fare')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Apply log transformation to 'Fare' to mitigate the impact of outliers
titanic_df['Fare'] = np.log1p(titanic_df['Fare'])
print(titanic_df)
# Out:
#      Survived  Sex   Age  SibSp  Parch      Fare Cabin  Embarked_Q  \
# 0           0    0  22.0      1      0  1.134691   NaN       False
# 1           1    1  38.0      1      0  1.664038   C85       False
# 2           1    1  26.0      0      0  1.159662   NaN       False
# 3           1    1  35.0      1      0  1.607603  C123       False
# 4           0    0  35.0      0      0  1.164014   NaN       False
# ..        ...  ...   ...    ...    ...       ...   ...         ...
# 886         0    0  27.0      0      0  1.291725   NaN       False
# 887         1    1  19.0      0      0  1.489299   B42       False
# 888         0    1   NaN      1      2  1.434282   NaN       False
# 889         1    0  26.0      0      0  1.489299  C148       False
# 890         0    0  32.0      0      0  1.153433   NaN        True
#
#      Embarked_S  Pclass_2  Pclass_3
# 0          True     False      True
# 1         False     False     False
# 2          True     False      True
# 3          True     False     False
# 4          True     False      True
# ..          ...       ...       ...
# 886        True      True     False
# 887        True     False     False
# 888        True     False      True
# 889       False     False     False
# 890       False     False      True
#
# [891 rows x 11 columns]

# %%
# Feature Engineering - Family Size
titanic_df['FamilySize'] = titanic_df['SibSp'] + titanic_df['Parch'] + 1
print(titanic_df)
# Out:
#      Survived  Sex   Age  SibSp  Parch      Fare Cabin  Embarked_Q  \
# 0           0    0  22.0      1      0  1.134691   NaN       False
# 1           1    1  38.0      1      0  1.664038   C85       False
# 2           1    1  26.0      0      0  1.159662   NaN       False
# 3           1    1  35.0      1      0  1.607603  C123       False
# 4           0    0  35.0      0      0  1.164014   NaN       False
# ..        ...  ...   ...    ...    ...       ...   ...         ...
# 886         0    0  27.0      0      0  1.291725   NaN       False
# 887         1    1  19.0      0      0  1.489299   B42       False
# 888         0    1   NaN      1      2  1.434282   NaN       False
# 889         1    0  26.0      0      0  1.489299  C148       False
# 890         0    0  32.0      0      0  1.153433   NaN        True
#
#      Embarked_S  Pclass_2  Pclass_3  FamilySize
# 0          True     False      True           2
# 1         False     False     False           2
# 2          True     False      True           1
# 3          True     False     False           2
# 4          True     False      True           1
# ..          ...       ...       ...         ...
# 886        True      True     False           1
# 887        True     False     False           1
# 888        True     False      True           4
# 889       False     False     False           1
# 890       False     False      True           1
#
# [891 rows x 12 columns]

# %%
# Age Distribution
sns.histplot(x='Age', data=titanic_df, kde=True)
plt.title('Distribution of Age')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Fare Distribution after log transformation
sns.histplot(x='Fare', data=titanic_df, kde=True)
plt.title('Distribution of Fare (after log transformation)')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Survival by Age Group
bins = [0, 12, 18, 30, 50, 100]
labels = ['Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']
titanic_df['AgeGroup'] = pd.cut(titanic_df['Age'], bins=bins, labels=labels)
sns.barplot(x='AgeGroup', y='Survived', data=titanic_df, order=labels)
plt.title('Survival Rate by Age Group')
plt.show()
# Out:
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vedha\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Drop or encode 'Cabin' column
titanic_df.drop(['Cabin'], axis=1, inplace=True)

# Explore correlations between numerical variables
numeric_columns = titanic_df.select_dtypes(include=[np.number]).columns
correlation_matrix = titanic_df[numeric_columns].corr()

# Plot the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
